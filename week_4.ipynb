# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)
df=pd.DataFrame({'A':np.random.randn(365).cumsum(0),
                'B':np.random.randn(365).cumsum(0)+20,
                'C':np.random.randn(365).cumsum(0)-20},
               index=pd.date_range('7/1/2021',periods=365))
df.head()
# Out:
#                    A          B          C
# 2021-07-01 -1.085631  20.059291 -20.230904
# 2021-07-02 -0.088285  21.803332 -16.659325
# 2021-07-03  0.194693  20.835588 -17.055481
# 2021-07-04 -1.311601  21.255156 -17.093802
# 2021-07-05 -1.890202  21.462083 -19.518638

# %%
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot('A','B',kind='scatter');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter('A','C',c='B', s=df['B'],colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='A', ylabel='C'>

# %%
ax=df.plot.scatter('A','C',c='B', s=df['B'],colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.box();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist(alpha=0.7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.kde(); #Which are useful for visualizing an estimate of a variable's probability density function. 
#Kernel density estimation plots come in handy in data science application
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
iris=pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
pd.tools.plotting.scatter_matrix(iris);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-de7dfd5f77fe> in <module>
# ----> 1 pd.tools.plotting.scatter_matrix(iris);
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'tools'

# %%
plt.figure()
pd.tools.plotting.parallel_coordinates(iris,'Name');
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d917c6bba74b> in <module>
#       1 plt.figure()
# ----> 2 pd.tools.plotting.parallel_coordinates(iris,'Name');
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'tools'

# %%
#SEABORN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(1234)
v1=pd.Series(np.random.normal(0,10,1000),name='v1')
v2=pd.Series(2*v1,np.random.normal(60,15,1000),name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50,150,5), label='v1');
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2');
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure();
plt.hist([v1,v2],histtype='barstacked',normed=True);
v3=np.concatenate((v1,v2))
sns.kdeplot(v3);
# Out:
# <div id='4254645f-8f80-4489-96d9-5f780bed45f5'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-95f47ec2d610> in <module>
#       1 plt.figure();
# ----> 2 plt.hist([v1,v2],histtype='barstacked',normed=True);
#       3 v3=np.concatenate((v1,v2))
#       4 sns.kdeplot(v3);
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', normed=True);
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3);
# Out:
# <div id='b2383a97-5902-43d5-89fd-27219c3ac89a'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-76dba45bd1b6> in <module>
#       1 plt.figure()
# ----> 2 plt.hist([v1, v2], histtype='barstacked', normed=True);
#       3 v3 = np.concatenate((v1,v2))
#       4 sns.kdeplot(v3);
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...

# %%
plt.figure()
sns.distplot(v3,hist_kws={'color','Teal'},kde_kws={'color','Navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-9f7aace3efb2> in <module>
#       1 plt.figure()
# ----> 2 sns.distplot(v3,hist_kws={'color','Teal'},kde_kws={'color','Navy'})
#
# NameError: name 'v3' is not defined
