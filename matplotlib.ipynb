# %%
# %matplotlib notebook

# %%
import matplotlib as mpl

# %%
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot
plt.plot?

# %%
plt.plot(3,2,'.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
fig=Figure()
canvas=FigureCanvasAgg(fig)
ax=fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img scr='test.png' />
# Out:
# <img scr='test.png' />

# %%
plt.figure()
plt.plot(3,2,'o')
ax=plt.gca()
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 6.0, 0.0, 10.0)

# %%
plt.figure()
plt.plot(2,5.5,'o')
plt.plot(3,9.5,'o')
plt.plot(4.5,12.5,'o')
plt.plot(5.5,14.5,'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=plt.gca()
ax.get_children()
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %%
import numpy as np
x=np.array([2,3,4,5,6,7,8])
y=x
colors=['green']*(len(x)-1)
colors.append('red')
plt.figure()
plt.scatter(x,y,s=100,c=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
zip_generator=zip([1,3,5,7,9],[0,2,4,6,8])
list(zip_generator)
# Out:
# [(1, 0), (3, 2), (5, 4), (7, 6), (9, 8)]

# %%
zip_generator=zip([1,3,5,7,9],[0,2,4,6,8])
x,y=zip(*zip_generator)
print(x)
print(y)
# Out:
# (1, 3, 5, 7, 9)
# (0, 2, 4, 6, 8)

# %%
plt.figure()
plt.scatter(x[:2],y[:2],s=100,c='red',label='Tall students')
plt.scatter(x[2:],y[2:],s=100,c='blue',label='short students')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('The number of times children kicked the ball')
plt.ylabel('The grade of student')
plt.title('Relationship between ball kicking and grades')
# Out:
# Text(0.5, 1.0, 'Relationship between ball kicking and grades')

# %%
plt.legend()

# %%
plt.legend(loc=4,frameon=False,title='Legend')

# %%
legend=plt.gca().get_children()[-2]

# %%
legend.get_children()[0].get_children()[1].get_children()[0].get_children()

# %%
from matplotlib.artist import Artist
def rec_gc(art, depth=0):
    if isinstance(art,Artist):
        print(" "*depth+str(art))
        for child in art.get_children():
            rec_gc(child,depth+2)
rec_gc(legend)
legend
# Out:
# Legend
# ...
#       Text(0, 0, 'Legend')
# ...
#             Text(0, 0, 'Tall students')
# ...
#             Text(0, 0, 'short students')
#   FancyBboxPatch((0, 0), width=1, height=1)

# %%
linear_data=np.array([1,2,3,4,5,6])
quadrant_data=linear_data**2
plt.figure()
plt.plot(linear_data,'-o',quadrant_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
plt.plot([2,3,4],'--r')

# %%
plt.xlabel('Some data')
plt.ylabel('SOme other data')
plt.title('A title')
plt.legend(['Baseline','Competetion','Us'])

# %%
plt.gca().fill_between(range(len(linear_data)),
                      linear_data, quadrant_data,
                      facecolor='blue',
                      alpha=0.25)

# %%
plt.figure()
observation_dates=np.arange('2017-01-01','2017-01-07',dtype='datetime64[D]')
plt.plot(observation_dates,linear_data,'-o',
        observation_dates,quadrant_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
import pandas as pd
plt.figure()
observation_dates=np.arange('2017-01-01','2017-01-07',dtype='datetime64[D]')
observation_dates=map(pd.to_datetime,observation_dates)
plt.plot(observation_dates,linear_data,'-o',
        observation_dates,quadrant_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-bdf72e2bddd2> in <module>
#       3 observation_dates=np.arange('2017-01-01','2017-01-07',dtype='datetime64[D]')
#       4 observation_dates=map(pd.to_datetime,observation_dates)
# ----> 5 plt.plot(observation_dates,linear_data,'-o',
#       6         observation_dates,quadrant_data,'-o')
#
# c:\users\zain ul abdin\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
plt.figure()
observation_dates=np.arange('2017-01-01','2017-01-07',dtype='datetime64[D]')
observation_dates=list(map(pd.to_datetime,observation_dates))
plt.plot(observation_dates,linear_data,'-o', 
         observation_dates,quadrant_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
wreck_gc()

# %%
x=plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)

# %%
ax=plt.gca()
ax.set_xlabel('Date')
ax.set_ylabel('Units')
ax.set_title('Quadrant vs Linear Performane')
# Out:
# Text(0.5, 1.0, 'Quadrant vs Linear Performane')

# %%
ax.set_title("Quadratic ($x^2$) vs Linear ($x$) Performace")
# Out:
# Text(0.5, 1.0, 'Quadratic ($x^2$) vs Linear ($x$) Performace')

# %%
plt.figure()
xvalues=range(len(linear_data))
plt.bar(xvalues,linear_data,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 6 artists>

# %%
new_xvalues=[]
for item in xvalues:
    new_xvalues.append(item+0.3)
plt.bar(new_xvalues,quadrant_data,width=0.3,color='red')
# Out:
# <BarContainer object of 6 artists>

# %%
from random import randint
linear_error=[randint(0,15) for x in range(len(linear_data))]
plt.bar(xvalues,linear_data,width=0.3,yerr=linear_error)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure()
xvalues=range(len(linear_data))
plt.bar(xvalues,linear_data,width=0.3,color='b')
plt.bar(xvalues,quadrant_data,width=0.3,bottom=linear_data, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 6 artists>

# %%
plt.figure()
xvalues=range(len(linear_data))
plt.barh(xvalues,linear_data,height=0.3,color='b')
plt.barh(xvalues,quadrant_data,height=0.3,left=linear_data, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 6 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
